# %%
import duckdb
import os

database = duckdb.connect("duck_db_analysis_database.db")

# %%
database.execute("SET external_threads=1").fetchdf()
#database.execute("SET log_query_path='duck_db_analysis_database.log'").fetchdf()
database.execute("SELECT * FROM duckdb_settings();").fetchdf()
# Out:
#                             name                             value  \
# 0                    access_mode                         automatic
# 1           checkpoint_threshold                            16.7MB
# 2         debug_checkpoint_abort                              NULL
# 3           debug_force_external                             False
# 4   debug_force_no_cross_product                             False
# 5    debug_many_free_list_blocks                             False
# 6              debug_window_mode                              NULL
# 7              default_collation
# 8                  default_order                               asc
# 9             default_null_order                       nulls_first
# 10           disabled_optimizers
# 11        enable_external_access                              True
# 12           enable_object_cache                             False
# 13              enable_profiling                              NULL
# ...
